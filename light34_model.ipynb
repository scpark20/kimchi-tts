# %%
import warnings
warnings.filterwarnings('ignore')

import os
import torch
from torch import nn

from hparams.light34_hparams import create_hparams
from model import Model
from datasets import LJDataset, TextMelCollate
from utils import sizeof_fmt, Logger

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Mon Mar  8 12:05:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.04    Driver Version: 455.23.04    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:19:00.0 Off |                  N/A |
# | 73%   65C    P2   272W / 370W |   9654MiB / 24268MiB |     96%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:68:00.0 Off |                  N/A |
# | 66%   75C    P2   238W / 350W |   5617MiB / 24265MiB |     44%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     20602      C   ...conda3/envs/ai/bin/python     4237MiB |
# |    0   N/A  N/A     21938      C   ...conda3/envs/ai/bin/python     5415MiB |
# |    1   N/A  N/A     21886      C   ...conda3/envs/ai/bin/python     5615MiB |
# +-----------------------------------------------------------------------------+

# %%
save_dir = 'save/light34_model'
logger = Logger(save_dir=save_dir, new=False)
print('done')
# Out:
# done

# %%
# !ls $save_dir
# Out:
# data.json  save_0

# %%
stt_hparams, tts_hparams = create_hparams()
model = Model(stt_hparams, tts_hparams)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=tts_hparams.lr, weight_decay=tts_hparams.weight_decay)

step = 0

size = sizeof_fmt(4 * sum(p.numel() for p in model.parameters()))
print(f"Model size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.parameters()))
print(f"TTS size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_encoder.parameters()))
print(f"MelEncoder size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_decoder.parameters()))
print(f"MelDecoder size {size}")

if False:
    model, optimizer, step = logger.load(step, model, optimizer)
print(step)

print('done')
# Out:
# Model size 80.9MiB
# TTS size 74.6MiB
# MelEncoder size 32.2MiB
# MelDecoder size 33.6MiB
# 0
# done

# %%
trainset = LJDataset(tts_hparams.root_dir)
collate_fn = TextMelCollate()
train_loader = torch.utils.data.DataLoader(trainset, num_workers=tts_hparams.num_workers, 
                          shuffle=True,
                          sampler=None,
                          batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)

print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7ffa17ffd210>

# %%
def to_cuda(batch):
    batch['text'] = batch['text'].cuda()
    batch['text_lengths'] = batch['text_lengths'].cuda()
    batch['mels'] = batch['mels'].cuda()
    batch['mel_lengths'] = batch['mel_lengths'].cuda()
    
    return batch

# %%
from IPython import display
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time

model.train()

while(True):
    
    for batch in train_loader:
        batch = to_cuda(batch)
        
        model.train()
        model.increase_step()
        model.zero_grad()

        stt_outputs, tts_outputs = model(batch)
        loss = tts_outputs['loss'] + stt_outputs['loss']
        loss.backward()
        
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
        print(grad_norm.mean())
        if torch.isnan(grad_norm.mean()):
            continue
        
        optimizer.step()
        
        if step % 5000 == 0:
            logger.save(step, model, optimizer)
        
        if step % 1 == 0:
            print('step :', step, 
                  'stt :', '%0.4f' % stt_outputs['loss'].item(),
                  'tts :', '%0.4f' % tts_outputs['loss'].item(),
                  'recon :', '%0.4f' % tts_outputs['recon_loss'].item(),
                  'kl :', '%0.4f' % tts_outputs['kl_loss'].item(),
                  'beta :', '%0.4f' % model.beta.item())
                  
            
        if step % 100 == 0:
            logger.log(step, 'stt_loss', stt_outputs['loss'].item())
            logger.log(step, 'tts_loss', tts_outputs['loss'].item())    
            logger.log(step, 'recon_loss', tts_outputs['recon_loss'].item())    
            logger.log(step, 'kl_loss', tts_outputs['kl_loss'].item())    
            logger.log(step, 'beta', model.beta.item())    
            
        if step % 100 == 0:
            display.clear_output()
            
            index = 3
            model.eval()
            
            with torch.no_grad():
                times = []
                for _ in range(10):
                    t0 = time.time()
                    samples, _ = model.inference(batch['text'], batch['mels'].size(2), stt_outputs["alignments"], temperature=0.7)
                    t1 = time.time()
                    times.append(t1 - t0)
                times = np.array(times)
                print('elapsed time :', np.mean(times))

            _tts_alignments = tts_outputs["alignments"].data.cpu().numpy()
            batch_size = _tts_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_tts_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            _stt_alignments = stt_outputs["alignments"].data.cpu().numpy()
            batch_size = _stt_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_stt_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _x = batch['mels'].data.cpu().numpy()
            librosa.display.specshow(_x[index])
            plt.colorbar()
            
            for i in range(_stt_alignments.shape[1]):
                plt.plot(_stt_alignments[index, i] * 100)
                
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _y = tts_outputs['pred'].data.cpu().numpy()
            librosa.display.specshow(_y[index])
            plt.colorbar()
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _s = samples.data.cpu().numpy()
            librosa.display.specshow(_s[index, :, :_y.shape[2]])
            plt.colorbar()
            plt.show()
                      
        step += 1
# Out:
# elapsed time : 0.014412474632263184
# tensor(1.6096, device='cuda:0')
# step : 1501 stt : 1.3791 tts : 2.7805 recon : 0.0045 kl : 0.0561 beta : 0.0301
# tensor(1.5199, device='cuda:0')
# step : 1502 stt : 1.4419 tts : 2.4863 recon : 0.0046 kl : 0.0535 beta : 0.0301
# tensor(1.2595, device='cuda:0')
# step : 1503 stt : 1.6117 tts : 2.0808 recon : 0.0041 kl : 0.0535 beta : 0.0301
# tensor(1.5477, device='cuda:0')
# step : 1504 stt : 1.4926 tts : 2.4177 recon : 0.0053 kl : 0.0541 beta : 0.0301
# tensor(2.5130, device='cuda:0')
# step : 1505 stt : 1.4552 tts : 2.4785 recon : 0.0041 kl : 0.0544 beta : 0.0301
# tensor(1.9464, device='cuda:0')
# step : 1506 stt : 1.4694 tts : 2.5288 recon : 0.0054 kl : 0.0546 beta : 0.0302
# tensor(1.5136, device='cuda:0')
# step : 1507 stt : 1.5120 tts : 2.4068 recon : 0.0046 kl : 0.0563 beta : 0.0302
# tensor(2.2977, device='cuda:0')
# step : 1508 stt : 1.4533 tts : 2.5329 recon : 0.0046 kl : 0.0562 beta : 0.0302
# tensor(1.4852, device='cuda:0')
# step : 1509 stt : 1.4515 tts : 2.5297 recon : 0.0049 kl : 0.0557 beta : 0.0302
# tensor(1.6587, device='cuda:0')
# step : 1510 stt : 1.7531 tts : 1.8189 recon : 0.0048 kl : 0.0595 beta : 0.0302
# tensor(1.9941, device='cuda:0')
# step : 1511 stt : 1.5033 tts : 2.4602 recon : 0.0046 kl : 0.0550 beta : 0.0303
# tensor(2.2372, device='cuda:0')
# step : 1512 stt : 1.4602 tts : 2.4556 recon : 0.0047 kl : 0.0558 beta : 0.0303
# tensor(2.9060, device='cuda:0')
# step : 1513 stt : 1.6701 tts : 2.0282 recon : 0.0061 kl : 0.0593 beta : 0.0303
# tensor(1.4526, device='cuda:0')
# step : 1514 stt : 1.4181 tts : 2.5603 recon : 0.0042 kl : 0.0549 beta : 0.0303
# tensor(1.3215, device='cuda:0')
# step : 1515 stt : 1.5073 tts : 2.2812 recon : 0.0042 kl : 0.0550 beta : 0.0303
# tensor(1.8845, device='cuda:0')
# step : 1516 stt : 1.5010 tts : 2.2634 recon : 0.0050 kl : 0.0570 beta : 0.0304
# tensor(1.3360, device='cuda:0')
# step : 1517 stt : 1.5199 tts : 2.2767 recon : 0.0042 kl : 0.0558 beta : 0.0304
# tensor(1.5333, device='cuda:0')
# step : 1518 stt : 1.5085 tts : 2.2721 recon : 0.0045 kl : 0.0553 beta : 0.0304
# tensor(1.6831, device='cuda:0')
# step : 1519 stt : 1.4206 tts : 2.4975 recon : 0.0039 kl : 0.0542 beta : 0.0304
# tensor(1.5420, device='cuda:0')
# step : 1520 stt : 1.3435 tts : 2.7112 recon : 0.0038 kl : 0.0532 beta : 0.0304
# tensor(1.5593, device='cuda:0')
# step : 1521 stt : 1.4804 tts : 2.2985 recon : 0.0041 kl : 0.0532 beta : 0.0305
# tensor(2.4098, device='cuda:0')
# step : 1522 stt : 1.5265 tts : 2.2680 recon : 0.0048 kl : 0.0544 beta : 0.0305
# tensor(1.4667, device='cuda:0')
# step : 1523 stt : 1.4642 tts : 2.4458 recon : 0.0042 kl : 0.0538 beta : 0.0305
# tensor(1.8276, device='cuda:0')
# step : 1524 stt : 1.2938 tts : 2.8349 recon : 0.0039 kl : 0.0525 beta : 0.0305
# tensor(1.8627, device='cuda:0')
# step : 1525 stt : 1.4297 tts : 2.4952 recon : 0.0039 kl : 0.0520 beta : 0.0305
# tensor(2.1845, device='cuda:0')
# step : 1526 stt : 1.5315 tts : 2.2199 recon : 0.0041 kl : 0.0530 beta : 0.0306
# tensor(1.7990, device='cuda:0')
# step : 1527 stt : 1.4100 tts : 2.6707 recon : 0.0046 kl : 0.0532 beta : 0.0306
# tensor(1.5972, device='cuda:0')
# step : 1528 stt : 1.3012 tts : 2.8163 recon : 0.0037 kl : 0.0525 beta : 0.0306
# tensor(1.8127, device='cuda:0')
# step : 1529 stt : 1.4537 tts : 2.4444 recon : 0.0043 kl : 0.0541 beta : 0.0306
# tensor(1.5571, device='cuda:0')
# step : 1530 stt : 1.7191 tts : 1.8203 recon : 0.0048 kl : 0.0571 beta : 0.0306
# tensor(1.8331, device='cuda:0')
# step : 1531 stt : 1.3372 tts : 2.7543 recon : 0.0041 kl : 0.0535 beta : 0.0307
# tensor(2.6354, device='cuda:0')
# step : 1532 stt : 1.5342 tts : 2.2387 recon : 0.0043 kl : 0.0550 beta : 0.0307
# tensor(1.9447, device='cuda:0')
# step : 1533 stt : 1.6454 tts : 1.9700 recon : 0.0048 kl : 0.0595 beta : 0.0307
# tensor(1.6899, device='cuda:0')
# step : 1534 stt : 1.3529 tts : 2.7172 recon : 0.0040 kl : 0.0561 beta : 0.0307
# tensor(1.8398, device='cuda:0')
# step : 1535 stt : 1.2373 tts : 3.1564 recon : 0.0038 kl : 0.0566 beta : 0.0307
# tensor(1.9743, device='cuda:0')
# step : 1536 stt : 1.3228 tts : 2.9529 recon : 0.0040 kl : 0.0533 beta : 0.0308
# tensor(1.9604, device='cuda:0')
# step : 1537 stt : 1.5498 tts : 2.2410 recon : 0.0058 kl : 0.0527 beta : 0.0308
# tensor(3.1848, device='cuda:0')
# step : 1538 stt : 1.5432 tts : 2.2396 recon : 0.0052 kl : 0.0524 beta : 0.0308
# tensor(1.6848, device='cuda:0')
# step : 1539 stt : 1.5325 tts : 2.3126 recon : 0.0054 kl : 0.0526 beta : 0.0308
# tensor(1.4091, device='cuda:0')
# step : 1540 stt : 1.5472 tts : 2.1587 recon : 0.0043 kl : 0.0525 beta : 0.0308
# tensor(2.3570, device='cuda:0')
# step : 1541 stt : 1.4746 tts : 2.3237 recon : 0.0043 kl : 0.0544 beta : 0.0309
# tensor(2.2938, device='cuda:0')
# step : 1542 stt : 1.5858 tts : 2.0583 recon : 0.0052 kl : 0.0568 beta : 0.0309
# tensor(3.8320, device='cuda:0')
# step : 1543 stt : 1.3205 tts : 2.7132 recon : 0.0039 kl : 0.0572 beta : 0.0309
# tensor(3.0837, device='cuda:0')
# step : 1544 stt : 1.6893 tts : 1.7490 recon : 0.0047 kl : 0.0626 beta : 0.0309
# tensor(1.8732, device='cuda:0')
# step : 1545 stt : 1.7049 tts : 1.6126 recon : 0.0051 kl : 0.0596 beta : 0.0309
# tensor(1.6146, device='cuda:0')
# step : 1546 stt : 1.5018 tts : 2.3814 recon : 0.0043 kl : 0.0571 beta : 0.0310
# tensor(1.9115, device='cuda:0')
# step : 1547 stt : 1.4613 tts : 2.5799 recon : 0.0037 kl : 0.0561 beta : 0.0310
# tensor(2.2190, device='cuda:0')
# step : 1548 stt : 1.4790 tts : 2.5455 recon : 0.0049 kl : 0.0561 beta : 0.0310
# tensor(2.5507, device='cuda:0')
# step : 1549 stt : 1.4726 tts : 2.6076 recon : 0.0039 kl : 0.0553 beta : 0.0310
# tensor(2.9303, device='cuda:0')
# step : 1550 stt : 1.5671 tts : 2.2987 recon : 0.0044 kl : 0.0561 beta : 0.0310
# tensor(2.1683, device='cuda:0')
# step : 1551 stt : 1.4402 tts : 2.5834 recon : 0.0040 kl : 0.0551 beta : 0.0311
# tensor(1.7044, device='cuda:0')
# step : 1552 stt : 1.3741 tts : 2.6360 recon : 0.0039 kl : 0.0547 beta : 0.0311
# tensor(2.1371, device='cuda:0')
# step : 1553 stt : 1.3570 tts : 2.6599 recon : 0.0036 kl : 0.0552 beta : 0.0311
# tensor(1.6303, device='cuda:0')
# step : 1554 stt : 1.4564 tts : 2.3630 recon : 0.0042 kl : 0.0545 beta : 0.0311
# tensor(3.1867, device='cuda:0')
# step : 1555 stt : 1.4605 tts : 2.3892 recon : 0.0040 kl : 0.0548 beta : 0.0311
# tensor(1.3973, device='cuda:0')
# step : 1556 stt : 1.5413 tts : 2.2066 recon : 0.0043 kl : 0.0557 beta : 0.0312
# tensor(1.3038, device='cuda:0')
# step : 1557 stt : 1.4997 tts : 2.2698 recon : 0.0043 kl : 0.0544 beta : 0.0312
# tensor(1.4832, device='cuda:0')
# step : 1558 stt : 1.3962 tts : 2.6204 recon : 0.0039 kl : 0.0532 beta : 0.0312
# tensor(1.2893, device='cuda:0')
# step : 1559 stt : 1.5194 tts : 2.2624 recon : 0.0038 kl : 0.0538 beta : 0.0312
# tensor(1.8402, device='cuda:0')
# step : 1560 stt : 1.2014 tts : 3.1714 recon : 0.0043 kl : 0.0524 beta : 0.0312
# tensor(1.9215, device='cuda:0')
# step : 1561 stt : 1.3780 tts : 2.5827 recon : 0.0036 kl : 0.0522 beta : 0.0313
# tensor(1.4073, device='cuda:0')
# step : 1562 stt : 1.5997 tts : 1.9898 recon : 0.0044 kl : 0.0533 beta : 0.0313
# tensor(2.2282, device='cuda:0')
# step : 1563 stt : 1.5081 tts : 2.2866 recon : 0.0043 kl : 0.0523 beta : 0.0313
# tensor(1.6677, device='cuda:0')
# step : 1564 stt : 1.4524 tts : 2.4207 recon : 0.0042 kl : 0.0521 beta : 0.0313
# tensor(2.2468, device='cuda:0')
# step : 1565 stt : 1.3455 tts : 2.6629 recon : 0.0054 kl : 0.0533 beta : 0.0313
# tensor(3.9706, device='cuda:0')
# step : 1566 stt : 1.4133 tts : 2.4760 recon : 0.0047 kl : 0.0527 beta : 0.0314
# tensor(3.7958, device='cuda:0')
# step : 1567 stt : 1.5875 tts : 2.0096 recon : 0.0046 kl : 0.0552 beta : 0.0314
# tensor(1.6519, device='cuda:0')
# step : 1568 stt : 1.5344 tts : 2.2114 recon : 0.0051 kl : 0.0544 beta : 0.0314
# tensor(1.7462, device='cuda:0')
# step : 1569 stt : 1.4571 tts : 2.4913 recon : 0.0052 kl : 0.0525 beta : 0.0314
# tensor(1.4686, device='cuda:0')
# step : 1570 stt : 1.7076 tts : 1.7285 recon : 0.0048 kl : 0.0583 beta : 0.0314
# tensor(1.5528, device='cuda:0')
# step : 1571 stt : 1.4000 tts : 2.5243 recon : 0.0054 kl : 0.0534 beta : 0.0315
# tensor(2.3828, device='cuda:0')
# step : 1572 stt : 1.3996 tts : 2.6652 recon : 0.0041 kl : 0.0529 beta : 0.0315
# tensor(1.8075, device='cuda:0')
# step : 1573 stt : 1.4326 tts : 2.5286 recon : 0.0051 kl : 0.0528 beta : 0.0315
# tensor(1.5613, device='cuda:0')
# step : 1574 stt : 1.4215 tts : 2.6315 recon : 0.0047 kl : 0.0535 beta : 0.0315
# tensor(1.7368, device='cuda:0')
# step : 1575 stt : 1.4386 tts : 2.4813 recon : 0.0044 kl : 0.0524 beta : 0.0315
# tensor(1.6555, device='cuda:0')
# step : 1576 stt : 1.3128 tts : 2.7996 recon : 0.0055 kl : 0.0521 beta : 0.0316
# tensor(2.1280, device='cuda:0')
# step : 1577 stt : 1.4368 tts : 2.4930 recon : 0.0042 kl : 0.0527 beta : 0.0316
# tensor(1.9866, device='cuda:0')
# step : 1578 stt : 1.2613 tts : 2.9126 recon : 0.0054 kl : 0.0527 beta : 0.0316
# tensor(2.8025, device='cuda:0')
# step : 1579 stt : 1.4746 tts : 2.3673 recon : 0.0047 kl : 0.0549 beta : 0.0316
# tensor(1.4390, device='cuda:0')
# step : 1580 stt : 1.4184 tts : 2.4538 recon : 0.0054 kl : 0.0528 beta : 0.0316
# tensor(2.9338, device='cuda:0')
# step : 1581 stt : 1.2873 tts : 2.8589 recon : 0.0062 kl : 0.0527 beta : 0.0317
# tensor(1.9322, device='cuda:0')
# step : 1582 stt : 1.3215 tts : 2.7880 recon : 0.0069 kl : 0.0521 beta : 0.0317
# tensor(1.5632, device='cuda:0')
# step : 1583 stt : 1.4834 tts : 2.4045 recon : 0.0065 kl : 0.0509 beta : 0.0317
# tensor(1.9352, device='cuda:0')
# step : 1584 stt : 1.3324 tts : 2.7874 recon : 0.0050 kl : 0.0496 beta : 0.0317
# tensor(3.6494, device='cuda:0')
# step : 1585 stt : 1.5216 tts : 2.2124 recon : 0.0064 kl : 0.0498 beta : 0.0317
# tensor(3.4168, device='cuda:0')
# step : 1586 stt : 1.5299 tts : 2.2617 recon : 0.0068 kl : 0.0504 beta : 0.0318
# tensor(1.6012, device='cuda:0')
# step : 1587 stt : 1.4607 tts : 2.4396 recon : 0.0045 kl : 0.0510 beta : 0.0318
# tensor(1.5306, device='cuda:0')
# step : 1588 stt : 1.5023 tts : 2.3539 recon : 0.0057 kl : 0.0522 beta : 0.0318
# tensor(1.5879, device='cuda:0')
# step : 1589 stt : 1.3033 tts : 2.7508 recon : 0.0055 kl : 0.0522 beta : 0.0318
# tensor(2.3606, device='cuda:0')
# step : 1590 stt : 1.1168 tts : 3.2996 recon : 0.0049 kl : 0.0532 beta : 0.0318
# tensor(3.0194, device='cuda:0')
# step : 1591 stt : 1.4291 tts : 2.5481 recon : 0.0044 kl : 0.0542 beta : 0.0319
# tensor(3.9264, device='cuda:0')
# step : 1592 stt : 1.3397 tts : 2.5705 recon : 0.0047 kl : 0.0533 beta : 0.0319
# tensor(1.4670, device='cuda:0')
# step : 1593 stt : 1.4400 tts : 2.3948 recon : 0.0046 kl : 0.0524 beta : 0.0319
# tensor(1.3792, device='cuda:0')
# step : 1594 stt : 1.4517 tts : 2.3454 recon : 0.0060 kl : 0.0507 beta : 0.0319
# tensor(1.7027, device='cuda:0')
# step : 1595 stt : 1.5293 tts : 2.1633 recon : 0.0040 kl : 0.0502 beta : 0.0319
# tensor(1.9929, device='cuda:0')
# step : 1596 stt : 1.3896 tts : 2.7103 recon : 0.0054 kl : 0.0487 beta : 0.0320
# tensor(2.4935, device='cuda:0')
# step : 1597 stt : 1.5361 tts : 2.1335 recon : 0.0044 kl : 0.0512 beta : 0.0320
# tensor(2.3725, device='cuda:0')
# step : 1598 stt : 1.2225 tts : 3.0623 recon : 0.0048 kl : 0.0486 beta : 0.0320
# tensor(2.0069, device='cuda:0')
# step : 1599 stt : 1.2536 tts : 2.8929 recon : 0.0037 kl : 0.0485 beta : 0.0320
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-695c79fb434b> in <module>
#      16         model.zero_grad()
#      17
# ---> 18         stt_outputs, tts_outputs = model(batch)
#      19         loss = tts_outputs['loss'] + stt_outputs['loss']
#      20         loss.backward()
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/model.py in forward(self, batch)
#      35
#      36     def forward(self, batch):
# ---> 37         stt_outputs = self.stt(batch)
#      38
#      39         self.beta = self._linear(0, 1, self.global_step, 0, self.hp.annealing_steps)
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, batch)
#     218         embedded_outputs = self.embedding(batch['text']).transpose(1, 2)
#     219         # logits : (b, c, l), alignments : (b, l, t), alignment_params : (b, l, c)
# --> 220         logits, alignments, alignment_params = self.decoder(encoded_inputs, embedded_outputs, batch['mel_lengths'])
#     221         loss = nn.CrossEntropyLoss()(logits.transpose(1, 2), batch['text'])
#     222
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, memory, decoder_inputs, memory_lengths)
#     193         while len(logits) < decoder_inputs.size(0) - 1:
#     194             decoder_input = decoder_inputs[len(logits)]
# --> 195             logit, alignment, param = self._decode(decoder_input)
#     196             logits.append(logit)
#     197             alignments.append(alignment)
#
# ~/ai/p2/kimchi-tts/STT.py in _decode(self, decoder_input)
#     160
#     161         # Attention
# --> 162         self.attention_context, weight, params = self.gaussian_attention(self.attention_hidden, self.memory, self.mask)
#     163
#     164         # Decoder
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, attention_hidden, memory, mask)
#      63         params = self.param_linear(attention_hidden)
#      64         # (b, l)
# ---> 65         weight = self._get_weight(params, memory.size(1))
#      66         if mask is not None:
#      67             weight.data.masked_fill_(mask, 0)
#
# ~/ai/p2/kimchi-tts/STT.py in _get_weight(self, params, length)
#      46
#      47         # Scale
# ---> 48         scale = torch.exp(params[:, 1:2]) * self.hp.scale_coeff
#      49
#      50         # Z
#
# KeyboardInterrupt:

# %%
logger.save(step, model, optimizer)
# Out:
# saved save/light34_model/save_1600

# %%
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time 

for batch in train_loader:
    batch = to_cuda(batch)
    break
        
model.eval()
with torch.no_grad():
    index = 0
    times = []
    for _ in range(100):
        t0 = time.time()
        samples, time_dict = model.inference(batch['text'][0:1], None, None, temperature=1.0)
        t1 = time.time()
        times.append(t1 - t0)
    times = np.array(times)
    print(samples.shape, np.mean(times))
    print(time_dict)
    
    plt.figure(figsize=[18, 3])
    _s = samples.data.cpu().numpy()
    librosa.display.specshow(_s[index])
    plt.colorbar()
    plt.show()
# Out:
# torch.Size([1, 80, 928]) 0.010047242641448975
# {'alignment': 0.0003428459167480469, 'random': 0.00027251243591308594, 'last_conv': 0.0025634765625, 'z_proj': 0.00025534629821777344, 'cond': 0.0007226467132568359, 'up': 0.0009088516235351562, 'encode': 0.0039005279541015625, 'pad': 2.7179718017578125e-05, 'enc_conv': 0.0009105205535888672, 'enc_lstm': 0.002867460250854492}

# %%
time_sum = 0
for key in time_dict.keys():
    time_sum += time_dict[key]

for key in time_dict.keys():
    print(key, '%0.2f' % (time_dict[key] / time_sum))
# Out:
# alignment 0.03
# random 0.02
# last_conv 0.20
# z_proj 0.02
# cond 0.06
# up 0.07
# encode 0.31
# pad 0.00
# enc_conv 0.07
# enc_lstm 0.22
