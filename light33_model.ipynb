# %%
import warnings
warnings.filterwarnings('ignore')

import os
import torch
from torch import nn

from hparams.light33_hparams import create_hparams
from model import Model
from datasets import LJDataset, TextMelCollate
from utils import sizeof_fmt, Logger

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Mon Mar  8 11:49:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.04    Driver Version: 455.23.04    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:19:00.0 Off |                  N/A |
# | 66%   58C    P2   195W / 370W |   4239MiB / 24268MiB |     53%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:68:00.0 Off |                  N/A |
# | 50%   72C    P2   245W / 350W |   5611MiB / 24265MiB |     82%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     20602      C   ...conda3/envs/ai/bin/python     4237MiB |
# |    1   N/A  N/A     21886      C   ...conda3/envs/ai/bin/python     5609MiB |
# +-----------------------------------------------------------------------------+

# %%
save_dir = 'save/light33_model'
logger = Logger(save_dir=save_dir, new=False)
print('done')
# Out:
# done

# %%
# !ls $save_dir
# Out:
# ls: cannot access 'save/light33_model': No such file or directory

# %%
stt_hparams, tts_hparams = create_hparams()
model = Model(stt_hparams, tts_hparams)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=tts_hparams.lr, weight_decay=tts_hparams.weight_decay)

step = 0

size = sizeof_fmt(4 * sum(p.numel() for p in model.parameters()))
print(f"Model size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.parameters()))
print(f"TTS size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_encoder.parameters()))
print(f"MelEncoder size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_decoder.parameters()))
print(f"MelDecoder size {size}")

if False:
    model, optimizer, step = logger.load(step, model, optimizer)
print(step)

print('done')
# Out:
# Model size 102.6MiB
# TTS size 96.2MiB
# MelEncoder size 32.2MiB
# MelDecoder size 55.3MiB
# 0
# done

# %%
trainset = LJDataset(tts_hparams.root_dir)
collate_fn = TextMelCollate()
train_loader = torch.utils.data.DataLoader(trainset, num_workers=tts_hparams.num_workers, 
                          shuffle=True,
                          sampler=None,
                          batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)

print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f9e2cfd31d0>

# %%
def to_cuda(batch):
    batch['text'] = batch['text'].cuda()
    batch['text_lengths'] = batch['text_lengths'].cuda()
    batch['mels'] = batch['mels'].cuda()
    batch['mel_lengths'] = batch['mel_lengths'].cuda()
    
    return batch

# %%
from IPython import display
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time

model.train()

while(True):
    
    for batch in train_loader:
        batch = to_cuda(batch)
        
        model.train()
        model.increase_step()
        model.zero_grad()

        stt_outputs, tts_outputs = model(batch)
        loss = tts_outputs['loss'] + stt_outputs['loss']
        loss.backward()
        
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
        print(grad_norm.mean())
        if torch.isnan(grad_norm.mean()):
            continue
        
        optimizer.step()
        
        if step % 5000 == 0:
            logger.save(step, model, optimizer)
        
        if step % 1 == 0:
            print('step :', step, 
                  'stt :', '%0.4f' % stt_outputs['loss'].item(),
                  'tts :', '%0.4f' % tts_outputs['loss'].item(),
                  'recon :', '%0.4f' % tts_outputs['recon_loss'].item(),
                  'kl :', '%0.4f' % tts_outputs['kl_loss'].item(),
                  'beta :', '%0.4f' % model.beta.item())
                  
            
        if step % 100 == 0:
            logger.log(step, 'stt_loss', stt_outputs['loss'].item())
            logger.log(step, 'tts_loss', tts_outputs['loss'].item())    
            logger.log(step, 'recon_loss', tts_outputs['recon_loss'].item())    
            logger.log(step, 'kl_loss', tts_outputs['kl_loss'].item())    
            logger.log(step, 'beta', model.beta.item())    
            
        if step % 100 == 0:
            display.clear_output()
            
            index = 3
            model.eval()
            
            with torch.no_grad():
                times = []
                for _ in range(10):
                    t0 = time.time()
                    samples, _ = model.inference(batch['text'], batch['mels'].size(2), stt_outputs["alignments"], temperature=0.7)
                    t1 = time.time()
                    times.append(t1 - t0)
                times = np.array(times)
                print('elapsed time :', np.mean(times))

            _tts_alignments = tts_outputs["alignments"].data.cpu().numpy()
            batch_size = _tts_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_tts_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            _stt_alignments = stt_outputs["alignments"].data.cpu().numpy()
            batch_size = _stt_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_stt_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _x = batch['mels'].data.cpu().numpy()
            librosa.display.specshow(_x[index])
            plt.colorbar()
            
            for i in range(_stt_alignments.shape[1]):
                plt.plot(_stt_alignments[index, i] * 100)
                
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _y = tts_outputs['pred'].data.cpu().numpy()
            librosa.display.specshow(_y[index])
            plt.colorbar()
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _s = samples.data.cpu().numpy()
            librosa.display.specshow(_s[index, :, :_y.shape[2]])
            plt.colorbar()
            plt.show()
                      
        step += 1
# Out:
# elapsed time : 0.012611150741577148
# tensor(1.8925, device='cuda:0')
# step : 4401 stt : 0.9655 tts : 0.4439 recon : 0.0047 kl : 0.0162 beta : 0.0881
# tensor(5.6343, device='cuda:0')
# step : 4402 stt : 1.0499 tts : 0.3661 recon : 0.0047 kl : 0.0181 beta : 0.0881
# tensor(10.3244, device='cuda:0')
# step : 4403 stt : 1.1345 tts : 0.3649 recon : 0.0049 kl : 0.0188 beta : 0.0881
# tensor(5.3568, device='cuda:0')
# step : 4404 stt : 1.2158 tts : 0.3621 recon : 0.0052 kl : 0.0199 beta : 0.0881
# tensor(5.0238, device='cuda:0')
# step : 4405 stt : 1.0409 tts : 0.3953 recon : 0.0067 kl : 0.0193 beta : 0.0881
# tensor(4.6372, device='cuda:0')
# step : 4406 stt : 1.0994 tts : 0.4273 recon : 0.0052 kl : 0.0191 beta : 0.0882
# tensor(2.5624, device='cuda:0')
# step : 4407 stt : 1.2199 tts : 0.3515 recon : 0.0048 kl : 0.0192 beta : 0.0882
# tensor(1.7438, device='cuda:0')
# step : 4408 stt : 1.0729 tts : 0.3851 recon : 0.0038 kl : 0.0189 beta : 0.0882
# tensor(1.1410, device='cuda:0')
# step : 4409 stt : 1.0538 tts : 0.4156 recon : 0.0037 kl : 0.0179 beta : 0.0882
# tensor(24.6228, device='cuda:0')
# step : 4410 stt : 1.0696 tts : 0.4016 recon : 0.0042 kl : 0.0170 beta : 0.0882
# tensor(1.3878, device='cuda:0')
# step : 4411 stt : 1.2001 tts : 0.3388 recon : 0.0060 kl : 0.0178 beta : 0.0883
# tensor(1.4313, device='cuda:0')
# step : 4412 stt : 1.1749 tts : 0.3389 recon : 0.0051 kl : 0.0180 beta : 0.0883
# tensor(10.9841, device='cuda:0')
# step : 4413 stt : 1.0945 tts : 0.4218 recon : 0.0040 kl : 0.0173 beta : 0.0883
# tensor(6.6388, device='cuda:0')
# step : 4414 stt : 1.0515 tts : 0.4067 recon : 0.0048 kl : 0.0180 beta : 0.0883
# tensor(1.5238, device='cuda:0')
# step : 4415 stt : 1.1777 tts : 0.3536 recon : 0.0070 kl : 0.0190 beta : 0.0883
# tensor(1.2315, device='cuda:0')
# step : 4416 stt : 1.0375 tts : 0.4220 recon : 0.0055 kl : 0.0180 beta : 0.0884
# tensor(3.8019, device='cuda:0')
# step : 4417 stt : 1.0568 tts : 0.3920 recon : 0.0043 kl : 0.0178 beta : 0.0884
# tensor(15.0567, device='cuda:0')
# step : 4418 stt : 0.9464 tts : 0.4966 recon : 0.0059 kl : 0.0178 beta : 0.0884
# tensor(1.5327, device='cuda:0')
# step : 4419 stt : 1.0727 tts : 0.4157 recon : 0.0091 kl : 0.0183 beta : 0.0884
# tensor(2.1890, device='cuda:0')
# step : 4420 stt : 1.0618 tts : 0.4417 recon : 0.0062 kl : 0.0174 beta : 0.0884
# tensor(6.4820, device='cuda:0')
# step : 4421 stt : 1.0925 tts : 0.4414 recon : 0.0076 kl : 0.0170 beta : 0.0885
# tensor(1.9571, device='cuda:0')
# step : 4422 stt : 1.1336 tts : 0.4075 recon : 0.0090 kl : 0.0178 beta : 0.0885
# tensor(5.3301, device='cuda:0')
# step : 4423 stt : 1.2013 tts : 0.3676 recon : 0.0063 kl : 0.0182 beta : 0.0885
# tensor(1.5369, device='cuda:0')
# step : 4424 stt : 0.9925 tts : 0.4504 recon : 0.0066 kl : 0.0178 beta : 0.0885
# tensor(0.9633, device='cuda:0')
# step : 4425 stt : 1.0354 tts : 0.4633 recon : 0.0048 kl : 0.0183 beta : 0.0885
# tensor(4.3780, device='cuda:0')
# step : 4426 stt : 1.0443 tts : 0.4421 recon : 0.0047 kl : 0.0201 beta : 0.0886
# tensor(4.8326, device='cuda:0')
# step : 4427 stt : 1.0921 tts : 0.4389 recon : 0.0071 kl : 0.0220 beta : 0.0886
# tensor(3.3457, device='cuda:0')
# step : 4428 stt : 1.1907 tts : 0.3506 recon : 0.0095 kl : 0.0236 beta : 0.0886
# tensor(13.0502, device='cuda:0')
# step : 4429 stt : 1.1340 tts : 0.3635 recon : 0.0103 kl : 0.0248 beta : 0.0886
# tensor(5.6389, device='cuda:0')
# step : 4430 stt : 0.9902 tts : 0.4281 recon : 0.0069 kl : 0.0231 beta : 0.0886
# tensor(3.9599, device='cuda:0')
# step : 4431 stt : 0.9460 tts : 0.5047 recon : 0.0055 kl : 0.0219 beta : 0.0887
# tensor(3.1075, device='cuda:0')
# step : 4432 stt : 1.0254 tts : 0.4335 recon : 0.0054 kl : 0.0197 beta : 0.0887
# tensor(5.3063, device='cuda:0')
# step : 4433 stt : 1.0684 tts : 0.4093 recon : 0.0040 kl : 0.0172 beta : 0.0887
# tensor(1.3906, device='cuda:0')
# step : 4434 stt : 1.0276 tts : 0.4335 recon : 0.0049 kl : 0.0160 beta : 0.0887
# tensor(3.8213, device='cuda:0')
# step : 4435 stt : 1.1306 tts : 0.3433 recon : 0.0048 kl : 0.0158 beta : 0.0887
# tensor(0.8597, device='cuda:0')
# step : 4436 stt : 0.9663 tts : 0.4228 recon : 0.0055 kl : 0.0155 beta : 0.0888
# tensor(4.1392, device='cuda:0')
# step : 4437 stt : 1.0722 tts : 0.4199 recon : 0.0039 kl : 0.0165 beta : 0.0888
# tensor(1.8151, device='cuda:0')
# step : 4438 stt : 1.0897 tts : 0.3772 recon : 0.0047 kl : 0.0181 beta : 0.0888
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-695c79fb434b> in <module>
#      18         stt_outputs, tts_outputs = model(batch)
#      19         loss = tts_outputs['loss'] + stt_outputs['loss']
# ---> 20         loss.backward()
#      21
#      22         grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
logger.save(step, model, optimizer)
# Out:
# saved save/light33_model/save_4439

# %%
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time 

for batch in train_loader:
    batch = to_cuda(batch)
    break
        
model.eval()
with torch.no_grad():
    index = 0
    times = []
    for _ in range(100):
        t0 = time.time()
        samples, time_dict = model.inference(batch['text'][0:1], None, None, temperature=1.0)
        t1 = time.time()
        times.append(t1 - t0)
    times = np.array(times)
    print(samples.shape, np.mean(times))
    print(time_dict)
    
    plt.figure(figsize=[18, 3])
    _s = samples.data.cpu().numpy()
    librosa.display.specshow(_s[index])
    plt.colorbar()
    plt.show()
# Out:
# torch.Size([1, 80, 984]) 0.009057104587554932
# {'alignment': 0.0004019737243652344, 'random': 0.00014638900756835938, 'last_conv': 0.0024118423461914062, 'z_proj': 0.0001404285430908203, 'cond': 0.0007829666137695312, 'up': 0.0009548664093017578, 'encode': 0.004151105880737305, 'pad': 3.075599670410156e-05, 'enc_conv': 0.0009226799011230469, 'enc_lstm': 0.0030808448791503906}

# %%
time_sum = 0
for key in time_dict.keys():
    time_sum += time_dict[key]

for key in time_dict.keys():
    print(key, '%0.2f' % (time_dict[key] / time_sum))
# Out:
# alignment 0.03
# random 0.01
# last_conv 0.19
# z_proj 0.01
# cond 0.06
# up 0.07
# encode 0.32
# pad 0.00
# enc_conv 0.07
# enc_lstm 0.24
