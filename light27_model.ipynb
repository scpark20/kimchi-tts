# %%
import warnings
warnings.filterwarnings('ignore')

import os
import torch
from torch import nn

from hparams.light27_hparams import create_hparams
from model import Model
from datasets import LJDataset, TextMelCollate
from utils import sizeof_fmt, Logger

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Sun Mar  7 23:57:32 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.04    Driver Version: 455.23.04    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:19:00.0 Off |                  N/A |
# | 59%   53C    P2   139W / 370W |   3457MiB / 24268MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:68:00.0 Off |                  N/A |
# | 50%   70C    P2   237W / 350W |  13436MiB / 24265MiB |     78%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     16597      C   ...conda3/envs/ai/bin/python     3455MiB |
# |    1   N/A  N/A     15868      C   ...conda3/envs/ai/bin/python     7749MiB |
# |    1   N/A  N/A     15986      C   ...conda3/envs/ai/bin/python     5685MiB |
# +-----------------------------------------------------------------------------+

# %%
save_dir = 'save/light27_model'
logger = Logger(save_dir=save_dir, new=False)
print('done')
# Out:
# done

# %%
# !ls $save_dir
# Out:
# ls: cannot access 'save/light27_model': No such file or directory

# %%
stt_hparams, tts_hparams = create_hparams()
model = Model(stt_hparams, tts_hparams)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=tts_hparams.lr, weight_decay=tts_hparams.weight_decay)

step = 0

size = sizeof_fmt(4 * sum(p.numel() for p in model.parameters()))
print(f"Model size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.parameters()))
print(f"TTS size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_encoder.parameters()))
print(f"MelEncoder size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_decoder.parameters()))
print(f"MelDecoder size {size}")

if False:
    model, optimizer, step = logger.load(step, model, optimizer)
print(step)

print('done')
# Out:
# Model size 23.4MiB
# TTS size 17.1MiB
# MelEncoder size 5.1MiB
# MelDecoder size 10.2MiB
# 0
# done

# %%
trainset = LJDataset(tts_hparams.root_dir)
collate_fn = TextMelCollate()
train_loader = torch.utils.data.DataLoader(trainset, num_workers=tts_hparams.num_workers, 
                          shuffle=True,
                          sampler=None,
                          batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)

print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f2d480b8190>

# %%
def to_cuda(batch):
    batch['text'] = batch['text'].cuda()
    batch['text_lengths'] = batch['text_lengths'].cuda()
    batch['mels'] = batch['mels'].cuda()
    batch['mel_lengths'] = batch['mel_lengths'].cuda()
    
    return batch

# %%
from IPython import display
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time 

model.train()

while(True):
    
    for batch in train_loader:
        batch = to_cuda(batch)
        
        model.train()
        model.increase_step()
        model.zero_grad()

        stt_outputs, tts_outputs = model(batch)
        loss = tts_outputs['loss'] + stt_outputs['loss']
        loss.backward()
        
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
        print(grad_norm.mean())
        if torch.isnan(grad_norm.mean()):
            continue
        
        optimizer.step()
        
        if step % 5000 == 0:
            logger.save(step, model, optimizer)
        
        if step % 1 == 0:
            print('step :', step, 
                  'stt :', '%0.4f' % stt_outputs['loss'].item(),
                  'tts :', '%0.4f' % tts_outputs['loss'].item(),
                  'recon :', '%0.4f' % tts_outputs['recon_loss'].item(),
                  'kl :', '%0.4f' % tts_outputs['kl_loss'].item(),
                  'beta :', '%0.4f' % model.beta.item())
                  
            
        if step % 100 == 0:
            logger.log(step, 'stt_loss', stt_outputs['loss'].item())
            logger.log(step, 'tts_loss', tts_outputs['loss'].item())    
            logger.log(step, 'recon_loss', tts_outputs['recon_loss'].item())    
            logger.log(step, 'kl_loss', tts_outputs['kl_loss'].item())    
            logger.log(step, 'beta', model.beta.item())    
            
        if step % 100 == 0:
            display.clear_output()
            
            index = 3
            model.eval()
            
            with torch.no_grad():
                times = []
                for _ in range(10):
                    t0 = time.time()
                    samples = model.inference(batch['text'], batch['mels'].size(2), stt_outputs["alignments"], temperature=0.7)
                    t1 = time.time()
                    times.append(t1 - t0)
                times = np.array(times)
                print('elapsed time :', np.mean(times))

            _tts_alignments = tts_outputs["alignments"].data.cpu().numpy()
            batch_size = _tts_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_tts_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            _stt_alignments = stt_outputs["alignments"].data.cpu().numpy()
            batch_size = _stt_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_stt_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _x = batch['mels'].data.cpu().numpy()
            librosa.display.specshow(_x[index])
            plt.colorbar()
            
            for i in range(_stt_alignments.shape[1]):
                plt.plot(_stt_alignments[index, i] * 100)
                
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _y = tts_outputs['pred'].data.cpu().numpy()
            librosa.display.specshow(_y[index])
            plt.colorbar()
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _s = samples.data.cpu().numpy()
            librosa.display.specshow(_s[index, :, :_y.shape[2]])
            plt.colorbar()
            plt.show()
                      
        step += 1
# Out:
# elapsed time : 0.01967780590057373
# tensor(1.4399, device='cuda:0')
# step : 20501 stt : 0.3923 tts : 0.1234 recon : 0.0036 kl : 0.0028 beta : 0.4101
# tensor(0.9400, device='cuda:0')
# step : 20502 stt : 0.2732 tts : 0.0928 recon : 0.0030 kl : 0.0025 beta : 0.4101
# tensor(1.0222, device='cuda:0')
# step : 20503 stt : 0.3162 tts : 0.1001 recon : 0.0034 kl : 0.0027 beta : 0.4101
# tensor(5.3225, device='cuda:0')
# step : 20504 stt : 0.2836 tts : 0.0953 recon : 0.0031 kl : 0.0025 beta : 0.4101
# tensor(1.2425, device='cuda:0')
# step : 20505 stt : 0.3160 tts : 0.0939 recon : 0.0030 kl : 0.0025 beta : 0.4101
# tensor(0.7563, device='cuda:0')
# step : 20506 stt : 0.2953 tts : 0.0940 recon : 0.0032 kl : 0.0025 beta : 0.4102
# tensor(1.1218, device='cuda:0')
# step : 20507 stt : 0.3004 tts : 0.0935 recon : 0.0029 kl : 0.0025 beta : 0.4102
# tensor(0.9464, device='cuda:0')
# step : 20508 stt : 0.2807 tts : 0.0923 recon : 0.0028 kl : 0.0025 beta : 0.4102
# tensor(1.7514, device='cuda:0')
# step : 20509 stt : 0.2725 tts : 0.0909 recon : 0.0027 kl : 0.0024 beta : 0.4102
# tensor(0.6871, device='cuda:0')
# step : 20510 stt : 0.2540 tts : 0.0841 recon : 0.0028 kl : 0.0024 beta : 0.4102
# tensor(1.4232, device='cuda:0')
# step : 20511 stt : 0.3132 tts : 0.1002 recon : 0.0028 kl : 0.0024 beta : 0.4103
# tensor(1.3099, device='cuda:0')
# step : 20512 stt : 0.3391 tts : 0.0988 recon : 0.0028 kl : 0.0025 beta : 0.4103
# tensor(0.8685, device='cuda:0')
# step : 20513 stt : 0.2907 tts : 0.0920 recon : 0.0032 kl : 0.0026 beta : 0.4103
# tensor(0.9983, device='cuda:0')
# step : 20514 stt : 0.2938 tts : 0.0913 recon : 0.0029 kl : 0.0024 beta : 0.4103
# tensor(0.9957, device='cuda:0')
# step : 20515 stt : 0.3400 tts : 0.1050 recon : 0.0033 kl : 0.0028 beta : 0.4103
# tensor(0.6854, device='cuda:0')
# step : 20516 stt : 0.2726 tts : 0.0861 recon : 0.0031 kl : 0.0026 beta : 0.4104
# tensor(1.1624, device='cuda:0')
# step : 20517 stt : 0.3348 tts : 0.1053 recon : 0.0029 kl : 0.0025 beta : 0.4104
# tensor(3.1735, device='cuda:0')
# step : 20518 stt : 0.3326 tts : 0.0991 recon : 0.0032 kl : 0.0026 beta : 0.4104
# tensor(1.0179, device='cuda:0')
# step : 20519 stt : 0.3000 tts : 0.0910 recon : 0.0027 kl : 0.0024 beta : 0.4104
# tensor(1.1049, device='cuda:0')
# step : 20520 stt : 0.2875 tts : 0.0913 recon : 0.0029 kl : 0.0025 beta : 0.4104
# tensor(4.1182, device='cuda:0')
# step : 20521 stt : 0.3319 tts : 0.1096 recon : 0.0032 kl : 0.0026 beta : 0.4105
# tensor(3.1593, device='cuda:0')
# step : 20522 stt : 0.2728 tts : 0.0961 recon : 0.0028 kl : 0.0025 beta : 0.4105
# tensor(0.9175, device='cuda:0')
# step : 20523 stt : 0.2785 tts : 0.1004 recon : 0.0032 kl : 0.0026 beta : 0.4105
# tensor(0.8263, device='cuda:0')
# step : 20524 stt : 0.3049 tts : 0.0975 recon : 0.0031 kl : 0.0025 beta : 0.4105
# tensor(0.6971, device='cuda:0')
# step : 20525 stt : 0.2255 tts : 0.0864 recon : 0.0028 kl : 0.0024 beta : 0.4105
# tensor(0.7714, device='cuda:0')
# step : 20526 stt : 0.3038 tts : 0.0968 recon : 0.0033 kl : 0.0026 beta : 0.4106
# tensor(1.6088, device='cuda:0')
# step : 20527 stt : 0.2888 tts : 0.1090 recon : 0.0035 kl : 0.0027 beta : 0.4106
# tensor(1.1216, device='cuda:0')
# step : 20528 stt : 0.2989 tts : 0.1023 recon : 0.0030 kl : 0.0025 beta : 0.4106
# tensor(1.0462, device='cuda:0')
# step : 20529 stt : 0.3065 tts : 0.0983 recon : 0.0031 kl : 0.0025 beta : 0.4106
# tensor(2.2755, device='cuda:0')
# step : 20530 stt : 0.3080 tts : 0.1000 recon : 0.0032 kl : 0.0025 beta : 0.4106
# tensor(1.5554, device='cuda:0')
# step : 20531 stt : 0.3158 tts : 0.1026 recon : 0.0030 kl : 0.0025 beta : 0.4107
# tensor(0.6381, device='cuda:0')
# step : 20532 stt : 0.2538 tts : 0.0893 recon : 0.0031 kl : 0.0025 beta : 0.4107
# tensor(2.7844, device='cuda:0')
# step : 20533 stt : 0.3198 tts : 0.0963 recon : 0.0031 kl : 0.0026 beta : 0.4107
# tensor(1.0433, device='cuda:0')
# step : 20534 stt : 0.2495 tts : 0.0914 recon : 0.0030 kl : 0.0025 beta : 0.4107
# tensor(2.0114, device='cuda:0')
# step : 20535 stt : 0.3066 tts : 0.1016 recon : 0.0035 kl : 0.0028 beta : 0.4107
# tensor(1.8041, device='cuda:0')
# step : 20536 stt : 0.2977 tts : 0.1002 recon : 0.0032 kl : 0.0025 beta : 0.4108
# tensor(1.5924, device='cuda:0')
# step : 20537 stt : 0.3038 tts : 0.0956 recon : 0.0032 kl : 0.0026 beta : 0.4108
# tensor(5.4759, device='cuda:0')
# step : 20538 stt : 0.3319 tts : 0.1162 recon : 0.0029 kl : 0.0024 beta : 0.4108
# tensor(3.4171, device='cuda:0')
# step : 20539 stt : 0.2826 tts : 0.0975 recon : 0.0031 kl : 0.0026 beta : 0.4108
# tensor(1.4194, device='cuda:0')
# step : 20540 stt : 0.3304 tts : 0.1050 recon : 0.0033 kl : 0.0027 beta : 0.4108
# tensor(0.9486, device='cuda:0')
# step : 20541 stt : 0.2589 tts : 0.0913 recon : 0.0029 kl : 0.0024 beta : 0.4109
# tensor(1.9317, device='cuda:0')
# step : 20542 stt : 0.2931 tts : 0.0941 recon : 0.0030 kl : 0.0025 beta : 0.4109
# tensor(2.0055, device='cuda:0')
# step : 20543 stt : 0.2551 tts : 0.0863 recon : 0.0026 kl : 0.0024 beta : 0.4109
# tensor(1.2827, device='cuda:0')
# step : 20544 stt : 0.3005 tts : 0.1019 recon : 0.0031 kl : 0.0026 beta : 0.4109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-928a4e63ad88> in <module>
#      16         model.zero_grad()
#      17
# ---> 18         stt_outputs, tts_outputs = model(batch)
#      19         loss = tts_outputs['loss'] + stt_outputs['loss']
#      20         loss.backward()
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/model.py in forward(self, batch)
#      35
#      36     def forward(self, batch):
# ---> 37         stt_outputs = self.stt(batch)
#      38
#      39         self.beta = self._linear(0, 1, self.global_step, 0, self.hp.annealing_steps)
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, batch)
#     214     def forward(self, batch):
#     215         # (b, c, t)
# --> 216         encoded_inputs = self.encoder(batch['mels'], batch['mel_lengths'])
#     217         # (b, c, l)
#     218         embedded_outputs = self.embedding(batch['text']).transpose(1, 2)
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, mels, input_lengths)
#     105         x = nn.utils.rnn.pack_padded_sequence(x, input_lengths, batch_first=True, enforce_sorted=False)
#     106         self.lstm.flatten_parameters()
# --> 107         x, _ = self.lstm(x)
#     108
#     109         # (b, t, c)
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     583         else:
#     584             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
# --> 585                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     586         output = result[0]
#     587         hidden = result[1:]
#
# KeyboardInterrupt:

# %%
logger.save(step, model, optimizer)
# Out:
# saved save/light27_model/save_20545

# %%
import numpy as np
import time 

model.eval()
with torch.no_grad():
    index = 0
    times = []
    for _ in range(100):
        t0 = time.time()
        samples = model.inference(batch['text'][0:1], batch['mels'].size(2), stt_outputs["alignments"][0:1], temperature=1.0)
        t1 = time.time()
        times.append(t1 - t0)
    times = np.array(times)
    print(samples.shape, np.mean(times))
    
    plt.figure(figsize=[18, 3])
    _s = samples.data.cpu().numpy()
    librosa.display.specshow(_s[index])
    plt.colorbar()
    plt.show()
