# %%
import warnings
warnings.filterwarnings('ignore')

import os
import torch
from torch import nn

from hparams.light24_hparams import create_hparams
from model import Model
from datasets import LJDataset, TextMelCollate
from utils import sizeof_fmt, Logger

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Sun Mar  7 21:59:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.04    Driver Version: 455.23.04    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:19:00.0 Off |                  N/A |
# | 43%   57C    P0   113W / 370W |      0MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:68:00.0 Off |                  N/A |
# | 30%   42C    P0    71W / 350W |      0MiB / 24265MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
save_dir = 'save/light24_model'
logger = Logger(save_dir=save_dir, new=False)
print('done')
# Out:
# done

# %%
# !ls $save_dir
# Out:
# ls: cannot access 'save/light24_model': No such file or directory

# %%
stt_hparams, tts_hparams = create_hparams()
model = Model(stt_hparams, tts_hparams)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=tts_hparams.lr, weight_decay=tts_hparams.weight_decay)

step = 0

size = sizeof_fmt(4 * sum(p.numel() for p in model.parameters()))
print(f"Model size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.parameters()))
print(f"TTS size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_encoder.parameters()))
print(f"MelEncoder size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_decoder.parameters()))
print(f"MelDecoder size {size}")

if False:
    model, optimizer, step = logger.load(step, model, optimizer)
print(step)

print('done')
# Out:
# Model size 17.2MiB
# TTS size 10.9MiB
# MelEncoder size 5.0MiB
# MelDecoder size 4.4MiB
# 0
# done

# %%
trainset = LJDataset(tts_hparams.root_dir)
collate_fn = TextMelCollate()
train_loader = torch.utils.data.DataLoader(trainset, num_workers=tts_hparams.num_workers, 
                          shuffle=True,
                          sampler=None,
                          batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)

print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f073aedf910>

# %%
def to_cuda(batch):
    batch['text'] = batch['text'].cuda()
    batch['text_lengths'] = batch['text_lengths'].cuda()
    batch['mels'] = batch['mels'].cuda()
    batch['mel_lengths'] = batch['mel_lengths'].cuda()
    
    return batch

# %%
from IPython import display
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time

model.train()

while(True):
    
    for batch in train_loader:
        batch = to_cuda(batch)
        
        model.train()
        model.increase_step()
        model.zero_grad()

        stt_outputs, tts_outputs = model(batch)
        loss = tts_outputs['loss'] + stt_outputs['loss']
        loss.backward()
        
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
        print(grad_norm.mean())
        if torch.isnan(grad_norm.mean()):
            continue
        
        optimizer.step()
        
        if step % 5000 == 0:
            logger.save(step, model, optimizer)
        
        if step % 1 == 0:
            print('step :', step, 
                  'stt :', '%0.4f' % stt_outputs['loss'].item(),
                  'tts :', '%0.4f' % tts_outputs['loss'].item(),
                  'recon :', '%0.4f' % tts_outputs['recon_loss'].item(),
                  'kl :', '%0.4f' % tts_outputs['kl_loss'].item(),
                  'beta :', '%0.4f' % model.beta.item())
                  
            
        if step % 100 == 0:
            logger.log(step, 'stt_loss', stt_outputs['loss'].item())
            logger.log(step, 'tts_loss', tts_outputs['loss'].item())    
            logger.log(step, 'recon_loss', tts_outputs['recon_loss'].item())    
            logger.log(step, 'kl_loss', tts_outputs['kl_loss'].item())    
            logger.log(step, 'beta', model.beta.item())    
            
        if step % 100 == 0:
            display.clear_output()
            
            index = 3
            model.eval()
            
            with torch.no_grad():
                times = []
                for _ in range(10):
                    t0 = time.time()
                    samples = model.inference(batch['text'], batch['mels'].size(2), stt_outputs["alignments"], temperature=0.7)
                    t1 = time.time()
                    times.append(t1 - t0)
                times = np.array(times)
                print('elapsed time :', np.mean(times))

            _tts_alignments = tts_outputs["alignments"].data.cpu().numpy()
            batch_size = _tts_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_tts_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            _stt_alignments = stt_outputs["alignments"].data.cpu().numpy()
            batch_size = _stt_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_stt_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _x = batch['mels'].data.cpu().numpy()
            librosa.display.specshow(_x[index])
            plt.colorbar()
            
            for i in range(_stt_alignments.shape[1]):
                plt.plot(_stt_alignments[index, i] * 100)
                
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _y = tts_outputs['pred'].data.cpu().numpy()
            librosa.display.specshow(_y[index])
            plt.colorbar()
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _s = samples.data.cpu().numpy()
            librosa.display.specshow(_s[index, :, :_y.shape[2]])
            plt.colorbar()
            plt.show()
                      
        step += 1
# Out:
# elapsed time : 0.021612000465393067
# tensor(0.6738, device='cuda:0')
# step : 24601 stt : 0.2286 tts : 0.1490 recon : 0.0034 kl : 0.0024 beta : 0.4922
# tensor(0.6787, device='cuda:0')
# step : 24602 stt : 0.2141 tts : 0.1556 recon : 0.0033 kl : 0.0024 beta : 0.4922
# tensor(0.7054, device='cuda:0')
# step : 24603 stt : 0.2146 tts : 0.1543 recon : 0.0033 kl : 0.0024 beta : 0.4922
# tensor(0.7294, device='cuda:0')
# step : 24604 stt : 0.2595 tts : 0.1624 recon : 0.0036 kl : 0.0024 beta : 0.4923
# tensor(0.8492, device='cuda:0')
# step : 24605 stt : 0.2624 tts : 0.1623 recon : 0.0037 kl : 0.0025 beta : 0.4923
# tensor(0.6415, device='cuda:0')
# step : 24606 stt : 0.2358 tts : 0.1813 recon : 0.0038 kl : 0.0025 beta : 0.4923
# tensor(1.7081, device='cuda:0')
# step : 24607 stt : 0.2551 tts : 0.1652 recon : 0.0035 kl : 0.0024 beta : 0.4923
# tensor(0.7990, device='cuda:0')
# step : 24608 stt : 0.2359 tts : 0.1603 recon : 0.0032 kl : 0.0023 beta : 0.4923
# tensor(0.7365, device='cuda:0')
# step : 24609 stt : 0.1865 tts : 0.1510 recon : 0.0032 kl : 0.0023 beta : 0.4924
# tensor(0.6536, device='cuda:0')
# step : 24610 stt : 0.2063 tts : 0.1561 recon : 0.0031 kl : 0.0023 beta : 0.4924
# tensor(0.7675, device='cuda:0')
# step : 24611 stt : 0.2247 tts : 0.1590 recon : 0.0031 kl : 0.0023 beta : 0.4924
# tensor(0.7827, device='cuda:0')
# step : 24612 stt : 0.2346 tts : 0.1621 recon : 0.0032 kl : 0.0023 beta : 0.4924
# tensor(0.6965, device='cuda:0')
# step : 24613 stt : 0.2489 tts : 0.1639 recon : 0.0035 kl : 0.0025 beta : 0.4924
# tensor(0.7205, device='cuda:0')
# step : 24614 stt : 0.2333 tts : 0.1601 recon : 0.0031 kl : 0.0023 beta : 0.4925
# tensor(0.6731, device='cuda:0')
# step : 24615 stt : 0.2283 tts : 0.1632 recon : 0.0033 kl : 0.0024 beta : 0.4925
# tensor(1.3017, device='cuda:0')
# step : 24616 stt : 0.1955 tts : 0.1506 recon : 0.0029 kl : 0.0022 beta : 0.4925
# tensor(0.7460, device='cuda:0')
# step : 24617 stt : 0.2412 tts : 0.1687 recon : 0.0033 kl : 0.0024 beta : 0.4925
# tensor(0.7200, device='cuda:0')
# step : 24618 stt : 0.2309 tts : 0.1609 recon : 0.0033 kl : 0.0024 beta : 0.4925
# tensor(0.5466, device='cuda:0')
# step : 24619 stt : 0.1891 tts : 0.1566 recon : 0.0032 kl : 0.0023 beta : 0.4926
# tensor(0.7811, device='cuda:0')
# step : 24620 stt : 0.2974 tts : 0.1782 recon : 0.0031 kl : 0.0023 beta : 0.4926
# tensor(0.8048, device='cuda:0')
# step : 24621 stt : 0.2626 tts : 0.1627 recon : 0.0035 kl : 0.0025 beta : 0.4926
# tensor(0.6680, device='cuda:0')
# step : 24622 stt : 0.2359 tts : 0.1547 recon : 0.0034 kl : 0.0024 beta : 0.4926
# tensor(1.3593, device='cuda:0')
# step : 24623 stt : 0.2456 tts : 0.1692 recon : 0.0038 kl : 0.0026 beta : 0.4926
# tensor(0.9302, device='cuda:0')
# step : 24624 stt : 0.2524 tts : 0.1543 recon : 0.0035 kl : 0.0025 beta : 0.4927
# tensor(0.6007, device='cuda:0')
# step : 24625 stt : 0.2224 tts : 0.1620 recon : 0.0032 kl : 0.0023 beta : 0.4927
# tensor(0.7469, device='cuda:0')
# step : 24626 stt : 0.2567 tts : 0.1637 recon : 0.0034 kl : 0.0024 beta : 0.4927
# tensor(2.0635, device='cuda:0')
# step : 24627 stt : 0.2811 tts : 0.1752 recon : 0.0034 kl : 0.0024 beta : 0.4927
# tensor(0.8337, device='cuda:0')
# step : 24628 stt : 0.1915 tts : 0.1618 recon : 0.0028 kl : 0.0021 beta : 0.4927
# tensor(0.9228, device='cuda:0')
# step : 24629 stt : 0.2527 tts : 0.1530 recon : 0.0032 kl : 0.0023 beta : 0.4928
# tensor(0.7256, device='cuda:0')
# step : 24630 stt : 0.1888 tts : 0.1457 recon : 0.0030 kl : 0.0022 beta : 0.4928
# tensor(0.6942, device='cuda:0')
# step : 24631 stt : 0.2241 tts : 0.1571 recon : 0.0035 kl : 0.0024 beta : 0.4928
# tensor(1.3483, device='cuda:0')
# step : 24632 stt : 0.2121 tts : 0.1539 recon : 0.0032 kl : 0.0024 beta : 0.4928
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-a92bc23aff71> in <module>
#      16         model.zero_grad()
#      17
# ---> 18         stt_outputs, tts_outputs = model(batch)
#      19         loss = tts_outputs['loss'] + stt_outputs['loss']
#      20         loss.backward()
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/model.py in forward(self, batch)
#      38
#      39         self.beta = self._linear(0, 1, self.global_step, 0, self.hp.annealing_steps)
# ---> 40         tts_outputs = self.tts(batch, stt_outputs, self.beta)
#      41
#      42         return stt_outputs, tts_outputs
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/TTS.py in forward(self, batch, stt_outputs, beta)
#     507     def forward(self, batch, stt_outputs, beta=1.0):
#     508
# --> 509         # (b, c, t)
#     510         x = batch['mels']
#     511         # (b, l)
#
# ~/ai/p2/kimchi-tts/TTS.py in _adjust_mean(self, params, lengths)
#     457         # Reconstruction Loss
#     458         recon_loss = ((pred - src) ** 2).sum(dim=[1, 2])
# --> 459
#     460         # KL-Divergence Loss
#     461         kl_loss = None
#
# KeyboardInterrupt:

# %%
logger.save(step, model, optimizer)
# Out:
# saved save/light24_model/save_24633

# %%
import numpy as np
import time 

model.eval()
with torch.no_grad():
    index = 0
    times = []
    for _ in range(100):
        t0 = time.time()
        samples = model.inference(batch['text'][0:1], batch['mels'].size(2), stt_outputs["alignments"][0:1], temperature=1.0)
        t1 = time.time()
        times.append(t1 - t0)
    times = np.array(times)
    print(samples.shape, np.mean(times))
    
    plt.figure(figsize=[18, 3])
    _s = samples.data.cpu().numpy()
    librosa.display.specshow(_s[index])
    plt.colorbar()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-c260a67d7477> in <module>
#       8     for _ in range(100):
#       9         t0 = time.time()
# ---> 10         samples = model.inference(batch['text'][0:1], batch['mels'].size(2), stt_outputs["alignments"][0:1], temperature=1.0)
#      11         t1 = time.time()
#      12         times.append(t1 - t0)
#
# ~/ai/p2/kimchi-tts/model.py in inference(self, cond, alignments, mel_length, temperature)
#      43
#      44     def inference(self, cond, alignments=None, mel_length=None, temperature=1.0):
# ---> 45         y = self.tts.inference(cond, alignments, mel_length, temperature)
#      46
#      47         return y
#
# ~/ai/p2/kimchi-tts/TTS.py in inference(self, cond, mel_length, alignments, temperature)
#     537
#     538         # (b, c, t)
# --> 539         cond = torch.bmm(cond, alignments)
#     540         # [(b, c, t)...]
#     541         conds = self.pooling(cond)
#
# RuntimeError: invalid argument 6: wrong matrix size at /opt/conda/conda-bld/pytorch_1603729047590/work/aten/src/THC/generic/THCTensorMathBlas.cu:41
