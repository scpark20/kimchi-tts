# %%
import warnings
warnings.filterwarnings('ignore')

import os
import torch
from torch import nn

from hparams.light22_hparams import create_hparams
from model import Model
from datasets import LJDataset, TextMelCollate
from utils import sizeof_fmt, Logger

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Mon Mar  8 00:05:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.04    Driver Version: 455.23.04    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:19:00.0 Off |                  N/A |
# | 70%   61C    P2   235W / 370W |   8106MiB / 24268MiB |     91%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:68:00.0 Off |                  N/A |
# | 55%   74C    P2   238W / 350W |  13436MiB / 24265MiB |     96%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     16597      C   ...conda3/envs/ai/bin/python     4163MiB |
# |    0   N/A  N/A     16628      C   ...conda3/envs/ai/bin/python     3941MiB |
# |    1   N/A  N/A     15868      C   ...conda3/envs/ai/bin/python     7749MiB |
# |    1   N/A  N/A     15986      C   ...conda3/envs/ai/bin/python     5685MiB |
# +-----------------------------------------------------------------------------+

# %%
save_dir = 'save/light22_model'
logger = Logger(save_dir=save_dir, new=False)
print('done')
# Out:
# done

# %%
stt_hparams, tts_hparams = create_hparams()
model = Model(stt_hparams, tts_hparams)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=tts_hparams.lr, weight_decay=tts_hparams.weight_decay)

step = 0

size = sizeof_fmt(4 * sum(p.numel() for p in model.parameters()))
print(f"Model size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.parameters()))
print(f"TTS size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_encoder.parameters()))
print(f"MelEncoder size {size}")

size = sizeof_fmt(4 * sum(p.numel() for p in model.tts.mel_decoder.parameters()))
print(f"MelDecoder size {size}")

if False:
    model, optimizer, step = logger.load(step, model, optimizer)
print(step)

print('done')
# Out:
# Model size 20.6MiB
# TTS size 14.3MiB
# MelEncoder size 8.2MiB
# MelDecoder size 4.5MiB
# 0
# done

# %%
trainset = LJDataset(tts_hparams.root_dir)
collate_fn = TextMelCollate()
train_loader = torch.utils.data.DataLoader(trainset, num_workers=tts_hparams.num_workers, 
                          shuffle=True,
                          sampler=None,
                          batch_size=tts_hparams.batch_size, pin_memory=False,
                          drop_last=True, collate_fn=collate_fn)

print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f75340880d0>

# %%
def to_cuda(batch, device='cuda'):
    if device == 'cuda':
        batch['text'] = batch['text'].cuda()
        batch['text_lengths'] = batch['text_lengths'].cuda()
        batch['mels'] = batch['mels'].cuda()
        batch['mel_lengths'] = batch['mel_lengths'].cuda()
    
    return batch

# %%
from IPython import display
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
import time 

model.train()

while(True):
    
    for batch in train_loader:
        batch = to_cuda(batch)
        
        model.train()
        model.increase_step()
        model.zero_grad()

        stt_outputs, tts_outputs = model(batch)
        loss = tts_outputs['loss'] + stt_outputs['loss']
        loss.backward()
        
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), 1)
        print(grad_norm.mean())
        if torch.isnan(grad_norm.mean()):
            continue
        
        optimizer.step()
        
        if step % 5000 == 0:
            logger.save(step, model, optimizer)
        
        if step % 1 == 0:
            print('step :', step, 
                  'stt :', '%0.4f' % stt_outputs['loss'].item(),
                  'tts :', '%0.4f' % tts_outputs['loss'].item(),
                  'recon :', '%0.4f' % tts_outputs['recon_loss'].item(),
                  'kl :', '%0.4f' % tts_outputs['kl_loss'].item(),
                  'beta :', '%0.4f' % model.beta.item())
                  
            
        if step % 100 == 0:
            logger.log(step, 'stt_loss', stt_outputs['loss'].item())
            logger.log(step, 'tts_loss', tts_outputs['loss'].item())    
            logger.log(step, 'recon_loss', tts_outputs['recon_loss'].item())    
            logger.log(step, 'kl_loss', tts_outputs['kl_loss'].item())    
            logger.log(step, 'beta', model.beta.item())    
            
        if step % 100 == 0:
            display.clear_output()
            
            index = 3
            model.eval()
            
            with torch.no_grad():
                times = []
                for _ in range(10):
                    t0 = time.time()
                    samples = model.inference(batch['text'], batch['mels'].size(2), stt_outputs["alignments"], temperature=0.7)
                    t1 = time.time()
                    times.append(t1 - t0)
                times = np.array(times)
                print('elapsed time :', np.mean(times))

            _tts_alignments = tts_outputs["alignments"].data.cpu().numpy()
            batch_size = _tts_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_tts_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            _stt_alignments = stt_outputs["alignments"].data.cpu().numpy()
            batch_size = _stt_alignments.shape[0]
            plt.figure(figsize=[18, 3])
            for i in range(3):
                plt.subplot(1, 3, i+1)
                plt.imshow(_stt_alignments[i].T, aspect='auto', origin='lower', interpolation='none')
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _x = batch['mels'].data.cpu().numpy()
            librosa.display.specshow(_x[index])
            plt.colorbar()
            
            for i in range(_stt_alignments.shape[1]):
                plt.plot(_stt_alignments[index, i] * 100)
                
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _y = tts_outputs['pred'].data.cpu().numpy()
            librosa.display.specshow(_y[index])
            plt.colorbar()
            plt.show()
            
            plt.figure(figsize=[18, 3])
            _s = samples.data.cpu().numpy()
            librosa.display.specshow(_s[index, :, :_y.shape[2]])
            plt.colorbar()
            plt.show()
                      
        step += 1
# Out:
# elapsed time : 0.030859923362731932
# tensor(1.6444, device='cuda:0')
# step : 14601 stt : 0.4290 tts : 0.1519 recon : 0.0034 kl : 0.0041 beta : 0.2921
# tensor(2.4107, device='cuda:0')
# step : 14602 stt : 0.4228 tts : 0.1673 recon : 0.0029 kl : 0.0039 beta : 0.2921
# tensor(1.2875, device='cuda:0')
# step : 14603 stt : 0.3789 tts : 0.1539 recon : 0.0030 kl : 0.0040 beta : 0.2921
# tensor(1.4816, device='cuda:0')
# step : 14604 stt : 0.4603 tts : 0.1541 recon : 0.0031 kl : 0.0040 beta : 0.2921
# tensor(1.2083, device='cuda:0')
# step : 14605 stt : 0.3550 tts : 0.1534 recon : 0.0028 kl : 0.0037 beta : 0.2922
# tensor(0.9466, device='cuda:0')
# step : 14606 stt : 0.4328 tts : 0.1556 recon : 0.0031 kl : 0.0040 beta : 0.2922
# tensor(1.4657, device='cuda:0')
# step : 14607 stt : 0.3734 tts : 0.1547 recon : 0.0029 kl : 0.0038 beta : 0.2922
# tensor(1.2112, device='cuda:0')
# step : 14608 stt : 0.3618 tts : 0.1454 recon : 0.0030 kl : 0.0037 beta : 0.2922
# tensor(18.2036, device='cuda:0')
# step : 14609 stt : 0.4302 tts : 0.1668 recon : 0.0031 kl : 0.0039 beta : 0.2922
# tensor(1.2743, device='cuda:0')
# step : 14610 stt : 0.3913 tts : 0.1473 recon : 0.0032 kl : 0.0039 beta : 0.2923
# tensor(1.0988, device='cuda:0')
# step : 14611 stt : 0.3262 tts : 0.1663 recon : 0.0029 kl : 0.0037 beta : 0.2923
# tensor(1.2677, device='cuda:0')
# step : 14612 stt : 0.3696 tts : 0.1533 recon : 0.0031 kl : 0.0039 beta : 0.2923
# tensor(1.2753, device='cuda:0')
# step : 14613 stt : 0.3979 tts : 0.1478 recon : 0.0033 kl : 0.0040 beta : 0.2923
# tensor(1.2322, device='cuda:0')
# step : 14614 stt : 0.3761 tts : 0.1451 recon : 0.0026 kl : 0.0035 beta : 0.2923
# tensor(1.0793, device='cuda:0')
# step : 14615 stt : 0.3709 tts : 0.1402 recon : 0.0033 kl : 0.0040 beta : 0.2924
# tensor(0.9951, device='cuda:0')
# step : 14616 stt : 0.4204 tts : 0.1587 recon : 0.0032 kl : 0.0040 beta : 0.2924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-928a4e63ad88> in <module>
#      16         model.zero_grad()
#      17
# ---> 18         stt_outputs, tts_outputs = model(batch)
#      19         loss = tts_outputs['loss'] + stt_outputs['loss']
#      20         loss.backward()
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/model.py in forward(self, batch)
#      35
#      36     def forward(self, batch):
# ---> 37         stt_outputs = self.stt(batch)
#      38
#      39         self.beta = self._linear(0, 1, self.global_step, 0, self.hp.annealing_steps)
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, batch)
#     218         embedded_outputs = self.embedding(batch['text']).transpose(1, 2)
#     219         # logits : (b, c, l), alignments : (b, l, t), alignment_params : (b, l, c)
# --> 220         logits, alignments, alignment_params = self.decoder(encoded_inputs, embedded_outputs, batch['mel_lengths'])
#     221         loss = nn.CrossEntropyLoss()(logits.transpose(1, 2), batch['text'])
#     222
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, memory, decoder_inputs, memory_lengths)
#     193         while len(logits) < decoder_inputs.size(0) - 1:
#     194             decoder_input = decoder_inputs[len(logits)]
# --> 195             logit, alignment, param = self._decode(decoder_input)
#     196             logits.append(logit)
#     197             alignments.append(alignment)
#
# ~/ai/p2/kimchi-tts/STT.py in _decode(self, decoder_input)
#     160
#     161         # Attention
# --> 162         self.attention_context, weight, params = self.gaussian_attention(self.attention_hidden, self.memory, self.mask)
#     163
#     164         # Decoder
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/ai/p2/kimchi-tts/STT.py in forward(self, attention_hidden, memory, mask)
#      63         params = self.param_linear(attention_hidden)
#      64         # (b, l)
# ---> 65         weight = self._get_weight(params, memory.size(1))
#      66         if mask is not None:
#      67             weight.data.masked_fill_(mask, 0)
#
# ~/ai/p2/kimchi-tts/STT.py in _get_weight(self, params, length)
#      46
#      47         # Scale
# ---> 48         scale = torch.exp(params[:, 1:2]) * self.hp.scale_coeff
#      49
#      50         # Z
#
# KeyboardInterrupt:

# %%
logger.save(step, model, optimizer)
# Out:
# saved save/light22_model/save_14617

# %%
import numpy as np
import time 

for batch in train_loader:
    batch = to_cuda(batch, None)

model.eval()
with torch.no_grad():
    index = 0
    times = []
    for _ in range(10):
        t0 = time.time()
        samples = model.inference(batch['text'][0:1], None, None, temperature=1.0)
        t1 = time.time()
        times.append(t1 - t0)
    times = np.array(times)
    print(samples.shape, np.mean(times))
    
    plt.figure(figsize=[18, 3])
    _s = samples.data.cpu().numpy()
    librosa.display.specshow(_s[index])
    plt.colorbar()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d26adbbc5106> in <module>
#       2 import time
#       3
# ----> 4 for batch in train_loader:
#       5     batch = to_cuda(batch, None)
#       6
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1066
#    1067             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1068             idx, data = self._get_data()
#    1069             self._tasks_outstanding -= 1
#    1070             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1032         else:
#    1033             while True:
# -> 1034                 success, data = self._try_get_data()
#    1035                 if success:
#    1036                     return data
#
# ~/anaconda3/envs/ai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     870         #   (bool: whether successfully get data, any: data if successful else None)
#     871         try:
# --> 872             data = self._data_queue.get(timeout=timeout)
#     873             return (True, data)
#     874         except Exception as e:
#
# ~/anaconda3/envs/ai/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# ~/anaconda3/envs/ai/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/anaconda3/envs/ai/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# ~/anaconda3/envs/ai/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     918
#     919             while True:
# --> 920                 ready = selector.select(timeout)
#     921                 if ready:
#     922                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/envs/ai/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
