# %%
import csv
import numpy as np

# %%
lines = []
for tag in ['GT', 'S4G', 'S5G', 'W4G', 'W5G']:
    for i in range(100):
        url = 'https://storage.googleapis.com/hvae_tts/exp1/inference_' + str(i) + '_' + tag + '.wav'
        lines.append(url)
        
np.random.shuffle(lines)
print(lines)
# Out:
# ['https://storage.googleapis.com/hvae_tts/exp1/inference_32_S5G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_92_W4G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_6_S4G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_88_W4G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_77_GT.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_64_W5G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_90_S5G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_78_W4G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_43_S4G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_66_S5G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_47_GT.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_85_S4G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_33_S5G.wav', 'https://storage.googleapis.com/hvae_tts/exp1/inference_75_S4G.wav', 'https://storage.googleapis.com/hv
# ...

# %%
with open('audio_url.csv', 'w', newline='') as csvfile:
    fieldnames = ['audio_url']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for l in lines:
        writer.writerow({'audio_url': l})

# %%
lines = []
for tag in ['GT', 'S5G1.0', 'S5G0.666', 'S5G0.333', 
            'W4G1.0', 'W4G0.666', 'W4G0.333']:
    for i in range(100):
        url = 'https://storage.googleapis.com/hvae_tts/exp2/inference_' + str(i) + '_' + tag + '.wav'
        lines.append(url)
        
np.random.shuffle(lines)
print(len(lines))
for line in lines:
    print(line)
# Out:
# 700
# https://storage.googleapis.com/hvae_tts/exp2/inference_89_S5G1.0.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_85_W4G0.333.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_48_S5G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_15_S5G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_26_S5G0.333.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_45_W4G0.333.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_80_S5G1.0.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_6_W4G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_18_W4G0.333.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_7_W4G0.333.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_87_S5G0.333.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_35_W4G1.0.wav
# https://storage.googleapis.com/hvae_tts/exp2/inference_38_S5G0.333.wav
# ...

# %%
with open('audio_url_exp2.csv', 'w', newline='') as csvfile:
    fieldnames = ['audio_url']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for l in lines:
        writer.writerow({'audio_url': l})

# %%
lines = []
for tag in ['GT', 'GTMEL', 'TACO2', 'FS', 'FS2', 'S5G0.666', 'W4G0.666']:
    for i in range(50):
        url = 'https://storage.googleapis.com/hvae_tts/exp3/inference_' + str(i) + '_' + tag + '.wav'
        lines.append(url)
        
np.random.shuffle(lines)
print(len(lines))
for line in lines:
    print(line)
# Out:
# 350
# https://storage.googleapis.com/hvae_tts/exp3/inference_41_S5G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_28_FS.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_49_W4G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_36_FS.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_34_FS.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_24_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_14_S5G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_35_FS.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_29_TACO2.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_8_S5G0.666.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_24_FS.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_6_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_25_FS.wav
# https://storage.googleapis.com/hvae_tts/exp3/inference_48_TACO2.wav
# ...

# %%
with open('audio_url_exp3.csv', 'w', newline='') as csvfile:
    fieldnames = ['audio_url']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for l in lines:
        writer.writerow({'audio_url': l})

# %%
lines = []
for tag in ['GT', 'GTMEL', 'TACO2', 'FS', 'FS2', 'S5G1.0', 'W4G1.0']:
    for i in range(50):
        url = 'https://storage.googleapis.com/hvae_tts/exp4/inference_' + str(i) + '_' + tag + '.wav'
        lines.append(url)
        
np.random.shuffle(lines)
print(len(lines))
for line in lines:
    print(line)
# Out:
# 350
# https://storage.googleapis.com/hvae_tts/exp4/inference_28_S5G1.0.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_47_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_25_TACO2.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_39_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_12_FS.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_10_FS2.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_44_FS2.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_44_S5G1.0.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_48_W4G1.0.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_25_FS2.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_33_GT.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_15_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_1_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp4/inference_11_FS2.wav
# ...

# %%
with open('audio_url_exp4.csv', 'w', newline='') as csvfile:
    fieldnames = ['audio_url']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for l in lines:
        writer.writerow({'audio_url': l})

# %%
lines = []
for tag in ['GTMEL', 'S5GN', 'S5G1', 'S5G2', 'S5G3']:
    for i in range(50):
        url = 'https://storage.googleapis.com/hvae_tts/exp5/inference_' + str(i) + '_' + tag + '.wav'
        lines.append(url)
        
np.random.shuffle(lines)
print(len(lines))
for line in lines:
    print(line)
# Out:
# 250
# https://storage.googleapis.com/hvae_tts/exp5/inference_14_S5G2.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_37_S5G2.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_22_S5G3.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_20_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_39_S5G1.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_24_S5GN.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_21_S5G2.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_23_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_16_S5G3.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_32_S5G1.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_24_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_21_GTMEL.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_9_S5G2.wav
# https://storage.googleapis.com/hvae_tts/exp5/inference_43_S5G2.wav
# ...

# %%
with open('audio_url_exp5.csv', 'w', newline='') as csvfile:
    fieldnames = ['audio_url']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for l in lines:
        writer.writerow({'audio_url': l})
